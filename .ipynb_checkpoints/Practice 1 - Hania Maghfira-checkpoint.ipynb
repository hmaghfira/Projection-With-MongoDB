# %% [markdown]
# ## Practice Case Day 1
#
# Connect cluster pymongo pada link berikut (pilih salah satu yang bisa) :
# - mongodb+srv://userstudent:admin1234@cluster0-nnbxe.gcp.mongodb.net/test?retryWrites=true&w=majority
# - mongodb+srv://mongodb-intro:admin1234@cluster0-nnbxe.gcp.mongodb.net/test?retryWrites=true&w=majority
# - mongodb+srv://adminuser12345:adminuser12345@cluster0-phmf4.gcp.mongodb.net/test?retryWrites=true&w=majority
# - mongodb+srv://admin12345:admin123@cluster0-snbhz.gcp.mongodb.net/test?retryWrites=true&w=majority
# - mongodb+srv://user1234:user1234@cluster0-1dcm4.gcp.mongodb.net/test?retryWrites=true&w=majority
# - mongodb+srv://admin1234:12345@cluster0-miqju.gcp.mongodb.net/test?retryWrites=true&w=majority
#
# #### Question
# 1. Membuat collection baru dengan nama clean_movies yang sama persis dengan movies collection pada database sample_mflix dengan memakai collection movies_intial (projecting_queries pymongo)
# 2. Validasi collection yang telah dibuat dengan parameter sbb :
#     1. Semua document pada clean_movies dan movie sama
#     2. Banyak document pada clean_movies dan movie sama
#     3. Semua fields pada clean_movies ada pada movie
#     4. Semua value pada clean_movies sama dengan semua value pada movies dengan urutan yang sama

# %% [markdown]
# ---

# %% [markdown]
# # Import Library

# %%
# import library
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# %% [markdown]
# # Connect to MongoDB
# Firstly, we need to connect to MongoDB which have movies collection to match the values and connect to another MongoDB to store new collection.<br>
#
# **client** : connection to MongoDB which have movies collection.<br>
# **client_movies** : connection to store new collection.

# %%
# connect to MongoDB
client = MongoClient("mongodb+srv://userstudent:admin1234@cluster0-nnbxe.gcp.mongodb.net/test?retryWrites=true&w=majority")
client_movies = MongoClient("mongodb+srv://user1234:user1234@cluster0-1dcm4.gcp.mongodb.net/test?retryWrites=true&w=majority")

# %% [markdown]
# # Connect to sample_mflix database to get movies collection

# %%
# show db sample_mflix
db = client.sample_mflix #database
col_movies = db.movies #movies collection

# %%
# show movies field
pprint.pprint(list(col_movies.find_one()))
# Out:
# ['_id',
#  'plot',
#  'genres',
#  'runtime',
#  'cast',
#  'num_mflix_comments',
#  'poster',
#  'title',
#  'fullplot',
#  'countries',
#  'released',
#  'directors',
#  'writers',
#  'awards',
#  'lastupdated',
#  'year',
#  'imdb',
#  'type',
#  'tomatoes']

# %%
# matching imdb in movies collection
# so that the number of document in new collection is equal to number of document in movies collection
imdb = list(col_movies.find({}, {'_id':0, 'imdb':1}))
imdb_list=[]
print(len(imdb))
for y in imdb :
    imdb_list.append(list(y.values())[0])

imdb_list[:5]
# Out:
# 23541
# [{'id': 6517, 'rating': 6.3, 'votes': 162},
#  {'id': 8133, 'rating': 7.8, 'votes': 4680},
#  {'id': 12512, 'rating': 6.8, 'votes': 489},
#  {'id': 13025, 'rating': 7.8, 'votes': 3738},
#  {'id': 15498, 'rating': 7.1, 'votes': 327}]

# %% [markdown]
# # 1. Create New Collection

# %% [markdown]
# ### Pipeline to Create New Collection
# To create new collection named **clean_movies_hania**, we need to create pipeline that projects collection from movies_initial collection.<br>

# %%
pipeline = [
    {
        '$project' : {
            'title' : 1,
            'year' : 1,
            'directors' : {'$split' : ['$director', ', ']},
            'cast' : {'$split' : ['$cast', ', ']},
            'writers' : {'$split' : ['$writer', ', ']},
            'genres' : {'$split' : ['$genre', ', ']},
            'languages' : {'$split' : ['$language', ', ']},
            'num_mflix_comments' : '',
            'poster' : 1,
            'countries' : {'$split' : ['$country', ', ']},
            'plot' : 1,
            'fullplot' : '$fullplot',
            'rated' : '$rating',
            'released': {
                '$cond': {
                    'if': {'$ne': ["$released", ""]},
                    'then': {
                        '$dateFromString': {
                            'dateString': "$released"
                        }
                    },
                    'else': ""}},
            'runtime' : {"$cond": 
                            [{'$eq': ["$runtime", ""]}, 0 ,{'$arrayElemAt':[{'$split': [ "$runtime", " min" ]}, 0]}]
                       },
            'imdb' : {
                'id' : '$imdbID',
                'rating' : '$imdbRating',
                'votes' : '$imdbVotes',
                },
            'metacritic':{"$cond": [{"$eq": ["$metacritic", ""]}, "$nonExistinField", "$metacritic"]},
            'awards' : {
                'win' : {'$arrayElemAt' : [{'$split': [{'$arrayElemAt':[{'$split': ['$awards','win']}, -2]}, ' ']}, -1]},
                'nomination' : {'$arrayElemAt' : [{'$split': [{'$arrayElemAt':[{'$split': ['$awards','nomination']}, -2]}, ' ']}, -1]},
                'text' : '$awards',
                },
            'type' : 1,
            'lastupdated' : '$lastupdated',
            
            'tomatoes': {
                'viewer' : {
                            'rating' : '',
                            'numReviews' : '',
                            'meter' : '',
                            },
                'lastUpdated' : '',
                },
        }
    },
    {
        '$match':{'imdb': 
                      {'$in':[dict(sorted(imdb_list[x].items(), key=lambda x: x[0])) for x in range(len(imdb_list))]}
                 }
    },
    {
        '$out' : 'clean_movies_hania'
    }
]

clear_output ()
pprint.pprint(list(client_movies.sample_mflix.movies_initial.aggregate(pipeline)))
# Out:
# []

# %%
# import pymongo
# from pymongo import MongoClient, UpdateOne
# import pprint
# from datetime import datetime
# import re
# from IPython.display import clear_output

# runtime_pat = re.compile(r'([0-9]+) min')
# updates = []
# count = 0

# for movie in client_movies.sample_mflix.clean_movies_hania.find({}):

#     fields_to_set = {}
#     fields_to_unset = {}

#     for k,v in movie.copy().items():
#         if v == "" or v == [""]:
#             del movie[k]
#             fields_to_unset[k] = ""

#     if 'director' in movie:
#         fields_to_unset['director'] = ""
#         fields_to_set['directors'] = movie['director'].split(", ")
#     if 'writer' in movie:
#         fields_to_unset['writer'] = ""
#         fields_to_set['writers'] = movie['writer'].split(", ")
#     if 'genre' in movie:
#         fields_to_unset['genre'] = ""
#         fields_to_set['genres'] = movie['genre'].split(", ")
#     if 'language' in movie:
#         fields_to_unset['language'] = ""
#         fields_to_set['languages'] = movie['language'].split(", ")
#     if 'country' in movie:
#         fields_to_unset['country'] = ""
#         fields_to_set['countries'] = movie['country'].split(", ")
        
#     if 'fullplot' in movie:
#         fields_to_unset['fullplot'] = ""
#         fields_to_set['fullPlot'] = movie['fullplot']
#     if 'rating' in movie:
#         fields_to_unset['rating'] = ""
#         fields_to_set['rated'] = movie['rating']

#     imdb = {}
#     if 'imdbID' in movie:
#         fields_to_unset['imdbID'] = ""
#         imdb['id'] = movie['imdbID']
#     if 'imdbRating' in movie:
#         fields_to_unset['imdbRating'] = ""
#         imdb['rating'] = movie['imdbRating']
#     if 'imdbVotes' in movie:
#         fields_to_unset['imdbVotes'] = ""
#         imdb['votes'] = movie['imdbVotes']
#     if imdb:
#         fields_to_set['imdb'] = imdb

#     if 'runtime' in movie:
#         m = runtime_pat.match(movie['runtime']) 
#         if m:
#             fields_to_set['runtime'] = int(m.group(1))

#     update_doc = {}
#     if fields_to_set:
#         update_doc['$set'] = fields_to_set
#     if fields_to_unset:
#         update_doc['$unset'] = fields_to_unset
    
#     updates.append(UpdateOne({'_id': movie['_id']}, update_one))
    
#     count += 1
#     pprint.pprint(update_doc)

# #     db2.clean_movies_hania.update_one({'_id': movie['_id']}, update_doc)

# %% [markdown]
# # 2. Validation Collection

# %% [markdown]
# ### Connect to sample_mflix database to get clean_movies_hania collection

# %%
# show db sample_mflix
db2 = client_movies.sample_mflix #database

# %%
### show all db in cluster ###
print(client_movies.list_database_names())

### show all collection in used db ###
print(db2.list_collection_names())

col_mov = db2.clean_movies_hania #movies collection
# Out:
# ['movies_list', 'sample_mflix', 'admin', 'local']
# ['clean_movies_devita', 'clean_movies_adipta', 'movies_initial', 'clean_movies_hania', 'clean_movies_firli', 'clean_movies_tio', 'clean_movies_isra', 'clean_movies_febi']

# %% [markdown]
# ### A. Check whether all document in clean_movies_hania collection are same as movies collection

# %%
val=col_movies.find().sort('title') #movies collection
valuesmov=col_mov.find().sort('title') #clean_movies_hania collection

if val==valuesmov :
    print("Document is matching.")
else :
    print("Document is not matching.")
# Out:
# Document is not matching.

# %% [markdown]
# From the above, we can know that all document in clean_movies_hania collection is not matching with movies collection.

# %% [markdown]
# ### B. Check total documents of clean_movies_hania

# %%
# show all documents in clean_movies_hania
total_movies = list(col_movies.find({}, {'_id':0, 'imdb':1})) #document in movies collection
total = list(col_mov.find({}, {'_id':0, 'imdb':1})) #document in clean_movies_hania collection

print("Total documents in movies : ", len(total_movies))
print("Total documents in clean_movies_hania : ", len(total))
# Out:
# Total documents in movies :  23541
# Total documents in clean_movies_hania :  23539

# %% [markdown]
# From the above, we can know that total number of documents in clean_movies_hania is 23539, fewer 2 documents than movies collection.

# %%
# check why?
coll1 = list(col_movies.aggregate([{"$sortByCount":"$imdb"}])) #collection movies
coll2 = list(col_mov.aggregate([{"$sortByCount":"$imdb"}])) #collection clean_movies_hania

for i in coll1:
  if i not in coll2:
    print(i)
# Out:
# {'_id': {'id': 5, 'rating': 6.2, 'votes': 1189}, 'count': 2}

# %% [markdown]
# From the above, we can know that imdb with id 5 has 3 copies. It causes the number of documents in clean_movies_hania has 2 less documents.

# %% [markdown]
# ### C. Check whether fields in clean_movies_hania can be found in movies collection
# The flow to match the field :
# 1. Get unique fields from movies collection
# 2. Get unique fields from clean_movies_hania collection
# 3. Match clean_movies_hania's fields to movies's fields

# %%
# show movies collection field
z=set([j for i in [list(doc.keys()) for doc in col_movies.find({})] for j in i])
z
# Out:
# {'_id',
#  'awards',
#  'cast',
#  'countries',
#  'directors',
#  'fullplot',
#  'genres',
#  'imdb',
#  'languages',
#  'lastupdated',
#  'metacritic',
#  'num_mflix_comments',
#  'plot',
#  'poster',
#  'rated',
#  'released',
#  'runtime',
#  'title',
#  'tomatoes',
#  'type',
#  'writers',
#  'year'}

# %%
# show clean_movies_hania collection field
field_mov=set([j for i in [list(doc.keys()) for doc in col_mov.find({})] for j in i])
field_mov
# Out:
# {'_id',
#  'awards',
#  'cast',
#  'countries',
#  'directors',
#  'fullplot',
#  'genres',
#  'imdb',
#  'languages',
#  'lastupdated',
#  'metacritic',
#  'num_mflix_comments',
#  'plot',
#  'poster',
#  'rated',
#  'released',
#  'runtime',
#  'title',
#  'tomatoes',
#  'type',
#  'writers',
#  'year'}

# %%
# show movies collection
# field=(list(col_movies.find_one()))
# fieldmov=(list(col_mov.find_one()))

# check both field
for i in field_mov:
  if i not in z:
    count = 0
  else :
    count = 1

if count==0 :
    print("Fields are not matching.")
else :
    print("Fields are matching.")
# Out:
# Fields are matching.

# %% [markdown]
# From the above, we can know that all fields in clean_movies_hania can be found in movies collection.

# %% [markdown]
# ### D. Check whether all values in clean_movies_hania collection are same as in movies collection

# %%
list(db2.clean_movies_hania.find().sort)
# Out:
# [{'_id': ObjectId('5db003a2d0a60ca4acd0bee5'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Charles Kayser', 'John Ott'],
#   'countries': ['USA'],
#   'directors': ['William K.L. Dickson'],
#   'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#   'genres': ['Short'],
#   'imdb': {'id': 5, 'rating': 6.2, 'votes': 1189},
#   'languages': [''],
#   'lastupdated': '2015-08-26 00:03:50.133000000',
#   'num_mflix_comments': '',
#   'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#   'poster': '',
#   'rated': 'UNRATED',
#   'released': datetime.datetime(1893, 5, 9, 0, 0),
#   'runtime': '1',
#   'title': 'Blacksmith Scene',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': [''],
#   'year': 1893},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0beff'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['A.C. Abadie',
#    "Gilbert M. 'Broncho Billy' Anderson",
#    'George Barnes',
#    'Justus D. Barnes'],
#   'countries': ['USA'],
#   'directors': ['Edwin S. Porter'],
#   'fullplot': "Among the earliest existing films in American cinema - notable as the first film that presented a narrative story to tell - it depicts a group of cowboy outlaws who hold up a train and rob the passengers. They are then pursued by a Sheriff's posse. Several scenes have color included - all hand tinted.",
#   'genres': ['Short', 'Western'],
#   'imdb': {'id': 439, 'rating': 7.4, 'votes': 9847},
#   'languages': ['English'],
#   'lastupdated': '2015-08-13 00:27:59.177000000',
#   'num_mflix_comments': '',
#   'plot': 'A group of bandits stage a brazen train hold-up, only to find a determined posse hot on their heels.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTQ4NDE5MDcyNF5BMl5BanBnXkFtZTgwNDU3Njk5MTE@._V1_SX300.jpg',
#   'rated': 'TV-G',
#   'released': datetime.datetime(1903, 12, 1, 0, 0),
#   'runtime': '11',
#   'title': 'The Great Train Robbery',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': [''],
#   'year': 1903},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf06'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Martin Fuller',
#    'Mrs. William Bechtel',
#    'Walter Edwin',
#    'Ethel Jewett'],
#   'countries': ['USA'],
#   'directors': ['Harold M. Shaw'],
#   'fullplot': "Thanks to the Fresh Air Fund, a slum child escapes his drunken mother for a day's outing in the country. Upon arriving, he and the other children are told a story about a mythical land of no pain. Rather then return to the slum at day's end, the lad seeks to journey to that beautiful land beyond the sunset.",
#   'genres': ['Short', 'Drama', 'Fantasy'],
#   'imdb': {'id': 488, 'rating': 7.1, 'votes': 448},
#   'languages': ['English'],
#   'lastupdated': '2015-08-29 00:27:45.437000000',
#   'num_mflix_comments': '',
#   'plot': 'A young boy, opressed by his mother, goes on an outing in the country with a social welfare group where he dares to dream of a land where the cares of his ordinary life fade.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTMzMDcxMjgyNl5BMl5BanBnXkFtZTcwOTgxNjg4Mg@@._V1_SX300.jpg',
#   'rated': 'UNRATED',
#   'released': datetime.datetime(1912, 10, 28, 0, 0),
#   'runtime': '14',
#   'title': 'The Land Beyond the Sunset',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Dorothy G. Shore'],
#   'year': 1912},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf11'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Frank Powell',
#    'Grace Henderson',
#    'James Kirkwood',
#    'Linda Arvidson'],
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullplot': "A greedy tycoon decides, on a whim, to corner the world market in wheat. This doubles the price of bread, forcing the grain's producers into charity lines and further into poverty. The film continues to contrast the ironic differences between the lives of those who work to grow the wheat and the life of the man who dabbles in its sale for profit.",
#   'genres': ['Short', 'Drama'],
#   'imdb': {'id': 832, 'rating': 6.6, 'votes': 1375},
#   'languages': ['English'],
#   'lastupdated': '2015-08-13 00:46:30.660000000',
#   'num_mflix_comments': '',
#   'plot': "A greedy tycoon decides, on a whim, to corner the world market in wheat. This doubles the price of bread, forcing the grain's producers into charity lines and further into poverty. The film...",
#   'poster': '',
#   'rated': 'G',
#   'released': datetime.datetime(1909, 12, 13, 0, 0),
#   'runtime': '14',
#   'title': 'A Corner in Wheat',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': [''],
#   'year': 1909},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf1d'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Winsor McCay'],
#   'countries': ['USA'],
#   'directors': ['Winsor McCay', 'J. Stuart Blackton'],
#   'fullplot': 'Cartoonist Winsor McCay agrees to create a large set of drawings that will be photographed and made into a motion picture. The job requires plenty of drawing supplies, and the cartoonist must also overcome some mishaps caused by an assistant. Finally, the work is done, and everyone can see the resulting animated picture.',
#   'genres': ['Animation', 'Short', 'Comedy'],
#   'imdb': {'id': 1737, 'rating': 7.3, 'votes': 1034},
#   'languages': ['English'],
#   'lastupdated': '2015-08-29 01:09:03.030000000',
#   'num_mflix_comments': '',
#   'plot': 'Cartoon figures announce, via comic strip balloons, that they will move - and move they do, in a wildly exaggerated style.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTU5MTk0NDM5N15BMl5BanBnXkFtZTcwMDAyOTYxMQ@@._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1911, 4, 8, 0, 0),
#   'runtime': '7',
#   'title': 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Winsor McCay (comic strip "Little Nemo in Slumberland")',
#    'Winsor McCay (screenplay)'],
#   'year': 1911},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf32'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Jane Gail', 'Ethel Grandin', 'William H. Turner', 'Matt Moore'],
#   'countries': ['USA'],
#   'directors': ['George Loane Tucker'],
#   'fullplot': '',
#   'genres': ['Crime', 'Drama'],
#   'imdb': {'id': 3471, 'rating': 6, 'votes': 371},
#   'languages': ['English'],
#   'lastupdated': '2015-09-15 02:07:14.247000000',
#   'num_mflix_comments': '',
#   'plot': 'A woman, with the aid of her police officer sweetheart, endeavors to uncover the prostitution ring that has kidnapped her sister, and the philanthropist who secretly runs it.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTU2NDg2ODkxMV5BMl5BanBnXkFtZTcwOTQzNzAzMg@@._V1_SX300.jpg',
#   'rated': 'TV-PG',
#   'released': datetime.datetime(1913, 11, 24, 0, 0),
#   'runtime': '88',
#   'title': 'Traffic in Souls',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': [''],
#   'year': 1913},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf3a'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Winsor McCay', 'George McManus', 'Roy L. McCardell'],
#   'countries': ['USA'],
#   'directors': ['Winsor McCay'],
#   'fullplot': 'Winsor Z. McCay bets another cartoonist that he can animate a dinosaur. So he draws a big friendly herbivore called Gertie. Then he get into his own picture. Gertie walks through the picture, eats a tree, meets her creator, and takes him carefully on her back for a ride.',
#   'genres': ['Animation', 'Short', 'Comedy'],
#   'imdb': {'id': 4008, 'rating': 7.3, 'votes': 1837},
#   'languages': ['English'],
#   'lastupdated': '2015-08-18 01:03:15.313000000',
#   'num_mflix_comments': '',
#   'plot': 'The cartoonist, Winsor McCay, brings the Dinosaurus back to life in the figure of his latest creation, Gertie the Dinosaur.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTQxNzI4ODQ3NF5BMl5BanBnXkFtZTgwNzY5NzMwMjE@._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1914, 9, 15, 0, 0),
#   'runtime': '12',
#   'title': 'Gertie the Dinosaur',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Winsor McCay'],
#   'year': 1914},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf3f'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Stanley Hunt',
#    'Sarah Constance Smith Hunt',
#    'Mrs. George Walkus',
#    "Paddy 'Malid"],
#   'countries': ['USA'],
#   'directors': ['Edward S. Curtis'],
#   'fullplot': '',
#   'genres': ['Drama', 'History'],
#   'imdb': {'id': 4150, 'rating': 5.8, 'votes': 223},
#   'languages': ['English'],
#   'lastupdated': '2015-09-16 12:11:37.770000000',
#   'num_mflix_comments': '',
#   'plot': 'Original advertising for the film describes it as a drama of primitive life on the shores of the North Pacific...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjE3ODk0NTAwNF5BMl5BanBnXkFtZTcwNjU2MzYyMQ@@._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1914, 12, 7, 0, 0),
#   'runtime': '65',
#   'title': 'In the Land of the Head Hunters',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Edward S. Curtis (story)'],
#   'year': 1914},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf47'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Pearl White', 'Crane Wilbur', 'Paul Panzer', 'Edward Jos�'],
#   'countries': ['USA'],
#   'directors': ['Louis J. Gasnier', 'Donald MacKenzie'],
#   'fullplot': 'Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle\'s secretary has been named as her guardian until she marries, at which time she will officially take possession of her inheritance. Meanwhile, her "guardian" and his confederates constantly come up with schemes to get rid of Pauline so that he can get his hands on the money himself.',
#   'genres': ['Action'],
#   'imdb': {'id': 4465, 'rating': 7.6, 'votes': 744},
#   'languages': ['English'],
#   'lastupdated': '2015-09-12 00:01:18.647000000',
#   'num_mflix_comments': '',
#   'plot': "Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle's secretary has been named as her guardian until she marries, at which time she will officially take ...",
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMzgxODk1Mzk2Ml5BMl5BanBnXkFtZTgwMDg0NzkwMjE@._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1914, 3, 23, 0, 0),
#   'runtime': '199',
#   'title': 'The Perils of Pauline',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Charles W. Goddard (screenplay)',
#    'Basil Dickey (screenplay)',
#    'Charles W. Goddard (novel)',
#    'George B. Seitz',
#    'Bertram Millhauser'],
#   'year': 1914},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf4d'),
#   'awards': {'nomination': None, 'text': '2 wins.', 'win': ''},
#   'cast': ['Lillian Gish', 'Mae Marsh', 'Henry B. Walthall', 'Miriam Cooper'],
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullplot': "Two brothers, Phil and Ted Stoneman, visit their friends in Piedmont, South Carolina: the family Cameron. This friendship is affected by the Civil War, as the Stonemans and the Camerons must join up opposite armies. The consequences of the War in their lives are shown in connection to major historical events, like the development of the Civil War itself, Lincoln's assassination, and the birth of the Ku Klux Klan.",
#   'genres': ['Drama', 'History', 'Romance'],
#   'imdb': {'id': 4972, 'rating': 6.8, 'votes': 15715},
#   'languages': [''],
#   'lastupdated': '2015-09-11 00:32:27.763000000',
#   'num_mflix_comments': '',
#   'plot': "The Civil War divides friends and destroys families, but that's nothing compared to the anarchy in the black-ruled South after the war.",
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTY0ODUwNDc3NV5BMl5BanBnXkFtZTgwNDE3NTU4MDE@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'released': datetime.datetime(1915, 3, 3, 0, 0),
#   'runtime': '165',
#   'title': 'The Birth of a Nation',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Thomas Dixon Jr. (adapted from his novel: "The Clansman: An Historical Romance of the Ku Klux Klan")',
#    'Thomas Dixon Jr. (play)',
#    'Thomas Dixon Jr. (novel)',
#    'D.W. Griffith',
#    'Frank E. Woods'],
#   'year': 1915},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf52'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Fannie Ward', 'Sessue Hayakawa', 'Jack Dean', 'James Neill'],
#   'countries': ['USA'],
#   'directors': ['Cecil B. DeMille'],
#   'fullplot': "Edith Hardy uses charity funds for Wall Street investments in hopes of buying some new gowns. She loses all the money and borrows from wealthy oriental Tori. When her husband gives her the amount she borrowed, Tori won't take it back, branding her shoulder with a Japanese sign of his ownership. She shoots him. Her husband takes the blame. In court Edith reveals all to an angry mob.",
#   'genres': ['Drama'],
#   'imdb': {'id': 5078, 'rating': 6.5, 'votes': 1660},
#   'languages': ['English'],
#   'lastupdated': '2015-08-31 00:41:20.670000000',
#   'num_mflix_comments': '',
#   'plot': "A venal, spoiled stockbroker's wife impulsively embezzles $10,000 from the charity she chairs and desperately turns to a Burmese ivory trader to replace the stolen money.",
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjEzMjcxNTM5M15BMl5BanBnXkFtZTgwMzgwNjQ1MjE@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'released': datetime.datetime(1915, 12, 13, 0, 0),
#   'runtime': '59',
#   'title': 'The Cheat',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Hector Turnbull (scenario)', 'Jeanie Macpherson (scenario)'],
#   'year': 1915},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf5a'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['George Beban', 'Clara Williams', 'J. Frank Burke', 'Leo Willis'],
#   'countries': ['USA'],
#   'directors': ['Reginald Barker'],
#   'fullplot': 'An immigrant leaves his sweetheart in Italy to find a better life across the sea in the grimy slums of New York. They are eventually reunited and marry. But life in New York is hard and tragedy tarnishes their dream of a better life in the new world.',
#   'genres': ['Drama'],
#   'imdb': {'id': 5557, 'rating': 6.4, 'votes': 175},
#   'languages': ['English'],
#   'lastupdated': '2015-07-27 00:07:43.230000000',
#   'num_mflix_comments': '',
#   'plot': 'An immigrant leaves his sweetheart in Italy to find a better life across the sea in the grimy slums of New York. They are eventually reunited and marry. But life in New York is hard and ...',
#   'poster': '',
#   'rated': 'PASSED',
#   'released': datetime.datetime(1915, 1, 1, 0, 0),
#   'runtime': '78',
#   'title': 'The Italian',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Thomas H. Ince (story)', 'C. Gardner Sullivan (story)'],
#   'year': 1915},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf60'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['John McCann', 'James A. Marcus', 'Maggie Weston', 'Harry McCoy'],
#   'countries': ['USA'],
#   'directors': ['Raoul Walsh'],
#   'fullplot': 'At 10 years old, Owens becomes a ragged orphan when his sainted mother dies. The Conways, who are next door neighbors, take Owen in, but the constant drinking by Jim soon puts Owen on the street. By 17, Owen learns that might is right. By 25, Owen is the leader of his own gang who spend most of their time gambling and drinking. But Marie comes into the gangster area of town and everything changes for Owen as he falls for Marie. But he cannot tell her so, so he comes to her settlement to find education and inspiration. But soon, his old way of life will rise to confront him again.',
#   'genres': ['Biography', 'Crime', 'Drama'],
#   'imdb': {'id': 5960, 'rating': 6.8, 'votes': 626},
#   'languages': ['English'],
#   'lastupdated': '2015-08-14 01:28:18.957000000',
#   'num_mflix_comments': '',
#   'plot': 'At 10 years old, Owens becomes a ragged orphan when his sainted mother dies. The Conways, who are next door neighbors, take Owen in, but the constant drinking by Jim soon puts Owen on the ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTg0NjI1ODI0Nl5BMl5BanBnXkFtZTYwODY4NzY4._V1_SX300.jpg',
#   'rated': 'PASSED',
#   'released': datetime.datetime(1915, 9, 13, 0, 0),
#   'runtime': '72',
#   'title': 'Regeneration',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Owen Frawley Kildare (book)',
#    'Raoul Walsh (adapted from the book: "My Mamie Rose")',
#    'Carl Harbaugh (adapted from the book: "My Mamie Rose")'],
#   'year': 1915},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf64'),
#   'awards': {'nomination': '', 'text': '1 nomination.', 'win': None},
#   'cast': ['Musidora', '�douard Math�', 'Marcel L�vesque', 'Jean Aym�'],
#   'countries': ['France'],
#   'directors': ['Louis Feuillade'],
#   'fullplot': 'An intrepid reporter and his loyal friend battle a bizarre secret society of criminals known as The Vampires.',
#   'genres': ['Action', 'Adventure', 'Crime'],
#   'imdb': {'id': 6206, 'rating': 6.8, 'votes': 2878},
#   'languages': ['French'],
#   'lastupdated': '2015-09-02 00:24:27.333000000',
#   'num_mflix_comments': '',
#   'plot': 'An intrepid reporter and his loyal friend battle a bizarre secret society of criminals known as The Vampires.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTc1NTY3NDIzNl5BMl5BanBnXkFtZTgwNTIyODg5MTE@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'released': datetime.datetime(1916, 11, 23, 0, 0),
#   'runtime': '399',
#   'title': 'Les vampires',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Louis Feuillade'],
#   'year': 1915},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf67'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Howard C. Hickman', 'Enid Markey', 'Lola May', 'Kate Bruce'],
#   'countries': ['USA'],
#   'directors': ['Reginald Barker',
#    'Thomas H. Ince',
#    'Raymond B. West',
#    'Walter Edwards',
#    'David Hartford',
#    'Jay Hunt',
#    'J. Parker Read Jr.'],
#   'fullplot': 'Allegorical film about peace. A king starts a war, many of the women are against it, people are pressed into service. A count has constructed a submarine and gets the order to sink an ocean liner, that is also carrying - supposedly - ammunition for the enemy. The count refuses to fire the torpedos, and sinks the submarine. He survives, but in a limbo between death and life where he meets Jesus, who takes him over to preach peace. Naturally the king arrests him and sentences him to death for treason, but then Jesus shows him the real face of war.',
#   'genres': ['Drama'],
#   'imdb': {'id': 6517, 'rating': 6.3, 'votes': 162},
#   'languages': [''],
#   'lastupdated': '2015-04-30 02:13:27.863000000',
#   'num_mflix_comments': '',
#   'plot': 'Christ takes on the form of a pacifist count to end a senseless war.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjAwNTIxMjE5N15BMl5BanBnXkFtZTgwODc1Mjg1MzE@._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1916, 6, 2, 0, 0),
#   'runtime': '78',
#   'title': 'Civilization',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['C. Gardner Sullivan'],
#   'year': 1916},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf70'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['William S. Hart',
#    'Clara Williams',
#    'Jack Standing',
#    'Alfred Hollingsworth'],
#   'countries': ['USA'],
#   'directors': ['Charles Swickard', 'William S. Hart', 'Clifford Smith'],
#   'fullplot': "When Reverend Robert Henley and his sister Faith arrive in the town of Hell's Hinges, saloon owner Silk Miller and his cohorts sense danger to their evil ways. They hire gunman Blaze Tracy to run the minister out of town. But Blaze finds something in Faith Henley that turns him around, and soon Silk Miller and his compadres have Blaze to deal with.",
#   'genres': ['Romance', 'Western'],
#   'imdb': {'id': 6780, 'rating': 6.4, 'votes': 531},
#   'languages': ['English'],
#   'lastupdated': '2015-08-16 01:13:00.090000000',
#   'num_mflix_comments': '',
#   'plot': "In the wayward western town known as Hell's Hinges, a local tough guy is reformed by the faith of a good woman.",
#   'poster': '',
#   'rated': 'UNRATED',
#   'released': datetime.datetime(1916, 3, 5, 0, 0),
#   'runtime': '64',
#   'title': "Hell's Hinges",
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['C. Gardner Sullivan (screenplay)',
#    'C. Gardner Sullivan (story)'],
#   'year': 1916},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf76'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Lillian Gish',
#    'Spottiswoode Aitken',
#    'Mary Alden',
#    'Frank Bennett'],
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullplot': "Intolerance and its terrible effects are examined in four historical eras. In ancient Babylon, a mountain girl is caught up in the religious rivalry that leads to the city's downfall. In Judea, the hypocritical Pharisees condemn Jesus Christ. In 1572 Paris, unaware of the impending St. Bartholomew's Day Massacre, two young Huguenots prepare for marriage. Finally, in modern America, social reformers destroy the lives of a young woman and her beloved.",
#   'genres': ['Drama', 'History'],
#   'imdb': {'id': 6864, 'rating': 8, 'votes': 9880},
#   'languages': [''],
#   'lastupdated': '2015-09-05 00:01:19.580000000',
#   'num_mflix_comments': '',
#   'plot': 'The story of a poor young woman, separated by prejudice from her husband and baby, is interwoven with tales of intolerance from throughout history.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjM5Nzg2MTc3NF5BMl5BanBnXkFtZTgwODg0NDU5MTE@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'released': datetime.datetime(1916, 9, 5, 0, 0),
#   'runtime': '197',
#   'title': "Intolerance: Love's Struggle Throughout the Ages",
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['D.W. Griffith (scenario)', 'Anita Loos (titles)'],
#   'year': 1916},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf82'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Tyrone Power Sr.', 'Helen Riaume', 'Marie Walcamp', 'Cora Drew'],
#   'countries': ['USA'],
#   'directors': ['Phillips Smalley', 'Lois Weber'],
#   'fullplot': 'While prosecuting a physician for the death of a client after an abortion, the district attorney discovers that his wife helped her society friends and the daughter of her maid obtain and pay for abortions from the physician (and was perhaps herself also a client.)',
#   'genres': ['Drama'],
#   'imdb': {'id': 7558, 'rating': 5.9, 'votes': 247},
#   'languages': ['English'],
#   'lastupdated': '2015-09-07 00:51:32.560000000',
#   'num_mflix_comments': '',
#   'plot': "A District Attorney's outspoken stand on abortion gets him in trouble with the local community.",
#   'poster': '',
#   'rated': 'APPROVED',
#   'released': datetime.datetime(1916, 5, 1, 0, 0),
#   'runtime': '62',
#   'title': 'Where Are My Children?',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Lucy Payton (from the story by)',
#    'Franklin Hall (from the story by)',
#    'Lois Weber',
#    'Phillips Smalley'],
#   'year': 1916},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf89'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Charles Chaplin',
#    'Edna Purviance',
#    'Eric Campbell',
#    'Albert Austin'],
#   'countries': ['USA'],
#   'directors': ['Charles Chaplin'],
#   'fullplot': "Charlie is on his way to the USA. He wins in a card game, puts the money in Edna's bag (she and her sick mother have been robbed of everything). When he retrieves a little for himself he is accused of being a thief. Edna clears his name. Later, broke, Charlie finds a coin and goes into a restaurant. There he finds Edna, whose mother has died, and asks her to join him. When he reaches for the coin to pay for their meals it is missing (it has fallen through a hole in his pocket).",
#   'genres': ['Short', 'Comedy', 'Drama'],
#   'imdb': {'id': 8133, 'rating': 7.8, 'votes': 4680},
#   'languages': ['English'],
#   'lastupdated': '2015-09-17 04:52:02.293000000',
#   'num_mflix_comments': '',
#   'plot': 'Charlie is an immigrant who endures a challenging voyage and gets into trouble as soon as he arrives in America.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTQxNjA1Njc1NV5BMl5BanBnXkFtZTgwODUxMzU5MTE@._V1_SX300.jpg',
#   'rated': 'UNRATED',
#   'released': datetime.datetime(1917, 6, 17, 0, 0),
#   'runtime': '30',
#   'title': 'The Immigrant',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': [''],
#   'year': 1917},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf8c'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Mary Pickford',
#    'Madlaine Traverse',
#    'Charles Wellesley',
#    'Gladys Fairbanks'],
#   'countries': ['USA'],
#   'directors': ['Maurice Tourneur'],
#   'fullplot': "Gwen's family is rich, but her parents ignore her and most of the servants push her around, so she is lonely and unhappy. Her father is concerned only with making money, and her mother cares only about her social position. But one day a servant's irresponsibility creates a crisis that causes everyone to rethink what is important to them.",
#   'genres': ['Comedy', 'Drama', 'Family'],
#   'imdb': {'id': 8443, 'rating': 6.9, 'votes': 884},
#   'languages': ['English'],
#   'lastupdated': '2015-07-27 00:11:31.387000000',
#   'num_mflix_comments': '',
#   'plot': "Gwen's family is rich, but her parents ignore her and most of the servants push her around, so she is lonely and unhappy. Her father is concerned only with making money, and her mother ...",
#   'poster': '',
#   'rated': '',
#   'released': datetime.datetime(1917, 3, 5, 0, 0),
#   'runtime': '65',
#   'title': 'The Poor Little Rich Girl',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Eleanor Gates (play)', 'Frances Marion (scenario)'],
#   'year': 1917},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf93'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Douglas Fairbanks',
#    'Eileen Percy',
#    'Calvert Carter',
#    'Charles Stevens'],
#   'countries': ['USA'],
#   'directors': ['John Emerson'],
#   'fullplot': 'A rich young Easterner who has always wanted to live in "the Wild West" plans to move to a Western town. Unknown to him, the town\'s "wild" days are long gone, and it is an orderly, civilized place now. The townsmen, not wanting to lose a rich potential resident, contrive to make over the town to suit the young man\'s fantasy.',
#   'genres': ['Comedy', 'Western', 'Romance'],
#   'imdb': {'id': 8775, 'rating': 6.9, 'votes': 388},
#   'languages': ['English'],
#   'lastupdated': '2015-06-05 00:40:35.137000000',
#   'num_mflix_comments': '',
#   'plot': 'A rich young Easterner who has always wanted to live in "the Wild West" plans to move to a Western town. Unknown to him, the town\'s "wild" days are long gone, and it is an orderly, ...',
#   'poster': '',
#   'rated': '',
#   'released': datetime.datetime(1917, 6, 24, 0, 0),
#   'runtime': '72',
#   'title': 'Wild and Woolly',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Horace B. Carpenter (story)', 'John Emerson', 'Anita Loos'],
#   'year': 1917},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bf97'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Tula Belle', 'Robin Macdougall', 'Edwin E. Reed', 'Emma Lowry'],
#   'countries': ['USA'],
#   'directors': ['Maurice Tourneur'],
#   'fullplot': 'Two peasant children, Mytyl and Tyltyl, are led by Berylune, a fairy, to search for the Blue Bird of Happiness. Berylune gives Tyltyl a cap with a diamond setting, and when Tyltyl turns the diamond, the children become aware of and conversant with the souls of a Dog and Cat, as well as of Fire, Water, Bread, Light, and other presumably inanimate things. The troupe thus sets off to find the elusive Blue Bird of Happiness.',
#   'genres': ['Fantasy'],
#   'imdb': {'id': 8891, 'rating': 6.6, 'votes': 446},
#   'languages': ['English'],
#   'lastupdated': '2015-07-20 00:32:04.810000000',
#   'num_mflix_comments': '',
#   'plot': 'Two peasant children, Mytyl and Tyltyl, are led by Berylune, a fairy, to search for the Blue Bird of Happiness. Berylune gives Tyltyl a cap with a diamond setting, and when Tyltyl turns the...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BNjg2MDk0MjM5NV5BMl5BanBnXkFtZTYwMjc4MTg5._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1918, 3, 31, 0, 0),
#   'runtime': '75',
#   'title': 'The Blue Bird',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Maurice Maeterlinck (play)', 'Charles Maigne'],
#   'year': 1918},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfa5'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Lillian Gish',
#    'Richard Barthelmess',
#    'Donald Crisp',
#    'Arthur Howard'],
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullplot': 'Cheng Huan is a missionary whose goal is to bring the teachings of peace by Buddha to the civilized Anglo-Saxons. Upon landing in England, he is quickly disillusioned by the intolerance and apathy of the country. He becomes a storekeeper of a small shop. Out his window, he sees the young Lucy Burrows. She is regularly beaten by her prizefighter father, underfed and wears ragged clothes. Even in this deplorable condition, Cheng can see that she is a priceless beauty and he falls in love with her from afar. On the day that she passes out in front of his store, he takes her in and cares for her. With nothing but love in his heart, he dresses her in silks and provides food for her. Still weak, she stays in his shop that night and all that Cheng does is watch over her. The peace and happiness that he sees last only until Battling Burrows finds out that his daughter is with a foreigner.',
#   'genres': ['Drama', 'Romance'],
#   'imdb': {'id': 9968, 'rating': 7.7, 'votes': 6610},
#   'languages': [''],
#   'lastupdated': '2015-08-21 00:06:48.907000000',
#   'num_mflix_comments': '',
#   'plot': "A frail waif, abused by her brutal boxer father in London's seedy Limehouse District, is befriended by a sensitive Chinese immigrant with tragic consequences.",
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjA5NjY4OTYwNV5BMl5BanBnXkFtZTgwODMwNzk5MTE@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'released': datetime.datetime(1919, 10, 20, 0, 0),
#   'runtime': '90',
#   'title': 'Broken Blossoms or The Yellow Man and the Girl',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Thomas Burke (adapted from a story by)', 'D.W. Griffith'],
#   'year': 1919},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfac'),
#   'awards': {'nomination': '', 'text': '1 nomination.', 'win': None},
#   'cast': ['Harold Lloyd',
#    'Mildred Davis',
#    "'Snub' Pollard",
#    'Peggy Cartwright'],
#   'countries': ['USA'],
#   'directors': ['Alfred J. Goulding', 'Hal Roach'],
#   'fullplot': "As a penniless man worries about how he will manage to eat, he is joined by a young waif and her dog, who are in the same predicament. Meanwhile, across town a dishonest lawyer is working with a gang of criminals, trying to swindle an innocent young heiress out of her inheritance. As the heiress is on her way home from the lawyer's office, she notices the young man and the waif in the midst of their latest problem with the authorities, and she rescues them. Later on, the young man will have an unexpected opportunity to repay her for her kindness.",
#   'genres': ['Comedy', 'Short', 'Action'],
#   'imdb': {'id': 10146, 'rating': 7, 'votes': 639},
#   'languages': ['English'],
#   'lastupdated': '2015-04-17 00:16:14.220000000',
#   'num_mflix_comments': '',
#   'plot': 'A penniless young man tries to save an heiress from kidnappers and help her secure her inheritance.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BNTU0NjcxNDg2OV5BMl5BanBnXkFtZTcwODMzOTAzMQ@@._V1_SX300.jpg',
#   'rated': 'TV-G',
#   'released': datetime.datetime(1919, 12, 28, 0, 0),
#   'runtime': '22',
#   'title': 'From Hand to Mouth',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['H.M. Walker (titles)'],
#   'year': 1919},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfc0'),
#   'awards': {'nomination': '', 'text': '1 nomination.', 'win': None},
#   'cast': ['Harold Lloyd', 'Roy Brooks', 'Mildred Davis', 'Wallace Howe'],
#   'countries': ['USA'],
#   'directors': ['Hal Roach'],
#   'fullplot': 'After a long wait, a young doctor finally has a patient come to his office. She is a young woman whose father has brought her to be treated for sleep-walking, but the father becomes annoyed with the doctor, and takes his daughter away. Soon afterward, the young doctor shares in a drinking binge with another doctor who has built a still in his office. After a series of misadventures, the two of them wind up in the same hotel where the daughter and her father are staying, leading to some hazardous predicaments.',
#   'genres': ['Comedy', 'Short'],
#   'imdb': {'id': 11293, 'rating': 7, 'votes': 646},
#   'languages': ['English'],
#   'lastupdated': '2015-08-11 00:35:33.717000000',
#   'num_mflix_comments': '',
#   'plot': 'A tipsy doctor encounters his patient sleepwalking on a building ledge, high above the street.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BNTU0NjcxNDg2OV5BMl5BanBnXkFtZTcwODMzOTAzMQ@@._V1_SX300.jpg',
#   'rated': 'PASSED',
#   'released': datetime.datetime(1920, 7, 11, 0, 0),
#   'runtime': '26',
#   'title': 'High and Dizzy',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Frank Terry (story)', 'H.M. Walker (titles)'],
#   'year': 1920},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfc4'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Wallace Beery', 'Barbara Bedford', 'Alan Roscoe', 'Lillian Hall'],
#   'countries': ['USA'],
#   'directors': ['Clarence Brown', 'Maurice Tourneur'],
#   'fullplot': 'As Alice and Cora Munro attempt to find their father, a British officer in the French and Indian War, they are set upon by French soldiers and their cohorts, Huron tribesmen led by the evil Magua. Fighting to rescue the women are Chingachgook and his son Uncas, the last of the Mohican tribe, and their white ally, the frontiersman Natty Bumppo, known as Hawkeye.',
#   'genres': ['Adventure', 'Drama'],
#   'imdb': {'id': 11387, 'rating': 6.9, 'votes': 773},
#   'languages': ['English'],
#   'lastupdated': '2015-07-19 00:12:27.010000000',
#   'num_mflix_comments': '',
#   'plot': 'As Alice and Cora Munro attempt to find their father, a British officer in the French and Indian War, they are set upon by French soldiers and their cohorts, Huron tribesmen led by the evil...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTg4OTMzNjY1Nl5BMl5BanBnXkFtZTgwMTU5NzgwMzE@._V1._CR49,47,273,392_SY132_CR1,0,89,132_AL_.jpg_V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'released': datetime.datetime(1920, 11, 21, 0, 0),
#   'runtime': '73',
#   'title': 'The Last of the Mohicans',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['James Fenimore Cooper (novel)', 'Robert Dillon (scenario)'],
#   'year': 1920},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfc9'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Buster Keaton', 'Sybil Seely'],
#   'countries': ['USA'],
#   'directors': ['Edward F. Cline', 'Buster Keaton'],
#   'fullplot': "Buster and Sybil exit a chapel as newlyweds. Among the gifts is a portable house you easily put together in one week. It doesn't help that Buster's rival for Sybil switches the numbers on the crates containing the house parts.",
#   'genres': ['Short', 'Comedy'],
#   'imdb': {'id': 11541, 'rating': 8.3, 'votes': 3942},
#   'languages': ['English'],
#   'lastupdated': '2015-05-07 01:07:01.633000000',
#   'num_mflix_comments': '',
#   'plot': "A newly wedded couple attempt to build a house with a prefabricated kit, unaware that a rival sabotaged the kit's component numbering.",
#   'poster': '',
#   'rated': 'TV-G',
#   'released': datetime.datetime(1920, 9, 1, 0, 0),
#   'runtime': '25',
#   'title': 'One Week',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': [''],
#   'year': 1920},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfcb'),
#   'awards': {'nomination': '', 'text': '1 nomination.', 'win': None},
#   'cast': ['Edward Jobson',
#    'Beulah Booker',
#    'Edward Connelly',
#    'Edward Alexander'],
#   'countries': ['USA'],
#   'directors': ['Herbert Blach�', 'Winchell Smith'],
#   'fullplot': "Nick Van Alstyne owns the Henrietta silver mine and is very rich. His son Bertie is naive and spoiled. His daughter Rose is married to shady investor Mark. Mark wrecks Bertie's wedding plans by making him take the blame for Mark's illegitimate daughter. Mark also nearly ruins the family business by selling off Henrietta stock at too low a price. Bertie, of all people, must come to the rescue on the trading floor.",
#   'genres': ['Comedy'],
#   'imdb': {'id': 11652, 'rating': 6.2, 'votes': 1020},
#   'languages': [''],
#   'lastupdated': '2015-06-20 00:38:08.303000000',
#   'num_mflix_comments': '',
#   'plot': 'The simple-minded son of a rich financier must find his own way in the world.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTI5NTc0ODAzMF5BMl5BanBnXkFtZTYwNTU3NDg4._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1920, 9, 1, 0, 0),
#   'runtime': '77',
#   'title': 'The Saphead',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Bronson Howard (original play "The Henrietta")',
#    'Victor Mapes (play)',
#    'June Mathis (scenario)',
#    'Winchell Smith (play)'],
#   'year': 1920},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfd1'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Evelyn Preer', 'Flo Clements', 'James D. Ruffin', 'Jack Chenault'],
#   'countries': ['USA'],
#   'directors': ['Oscar Micheaux'],
#   'fullplot': "Southern negro Sylvia Landry visits her cousin Alma in the north, where there is less racial prejudice than in her home town of Piney Woods in the deep south, and is anxiously awaiting her fianc�, Conrad. But Alma has designs on Conrad and tricks Sylvia into a compromising situation when he arrives, and he abandons her. Disheartened, she returns to Piney Woods to help a reverend running a school for young negroes. Sylvia learns that the reverend hasn't the heart to turn away poor students, and unless he can raise $5,000 to supplement the $1.49 per child per year that the state supplies, the school will be closed. She goes up north again to try to raise the money and has little success, but meets kindly negro, Dr. V. Vivian, who helps her regain her stolen purse. When she saves a child from being hit by an auto, she herself is slightly injured. But the owner of the car is philanthropist Mrs. Elena Warwick, who is sympathetic to her quest and promises to donate the $5,000 to the school. Her bigoted southern friend, Mrs. Stratton, tries to talk her out of the donation, and Mrs. Warwick gets so incensed she raises the amount to $50,000. Her job done, Sylvia returns to Piney Woods. But Dr. Vivian has fallen in love with Sylvia and goes to Alma to try to find her. There he learns the shocking details of her past and that of her family.",
#   'genres': ['Drama', 'Romance'],
#   'imdb': {'id': 11870, 'rating': 6.3, 'votes': 1138},
#   'languages': [''],
#   'lastupdated': '2015-08-21 00:15:06.017000000',
#   'num_mflix_comments': '',
#   'plot': 'Abandoned by her fianc�, an educated negro woman with a shocking past dedicates herself to helping a near bankrupt school for impoverished negro youths.',
#   'poster': '',
#   'rated': '',
#   'released': datetime.datetime(1920, 1, 12, 0, 0),
#   'runtime': '79',
#   'title': 'Within Our Gates',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Oscar Micheaux'],
#   'year': 1920},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfd2'),
#   'awards': {'nomination': '', 'text': '2 nominations.', 'win': None},
#   'cast': ['Lon Chaney', 'Leatrice Joy', 'John Bowers', 'Hardee Kirkland'],
#   'countries': ['USA'],
#   'directors': ['Wallace Worsley'],
#   'fullplot': "A secret society holds a meeting to determine what to do about a powerful and dangerous man whom they have been studying closely for the past three months. They all agree that he deserves to die. Two of the members, Farallone and Forrest, are both in love with Lilith, the group's only female member. But Lilith accepts neither of them, preferring to devote herself to the group's cause. When the group meets again and deals cards to all the members, Forrest draws the ace of hearts, meaning that he will be the one to carry out the assassination. Lilith then suddenly agrees to marry him, in order to give him courage. But after their first night together, both of them begin to feel differently about what they have planned.",
#   'genres': ['Crime', 'Drama', 'Mystery'],
#   'imdb': {'id': 11904, 'rating': 7, 'votes': 798},
#   'languages': [''],
#   'lastupdated': '2015-07-20 00:01:29.560000000',
#   'num_mflix_comments': '',
#   'plot': 'A romantic rivalry among members of a secret society becomes even tenser when one of the men is assigned to carry out an assassination.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTkwOTUyNDk1N15BMl5BanBnXkFtZTYwODI3MzI3._V1_SX300.jpg',
#   'rated': 'PASSED',
#   'released': datetime.datetime(1924, 4, 4, 0, 0),
#   'runtime': '75',
#   'title': 'The Ace of Hearts',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Gouverneur Morris (by)', 'Ruth Wightman (scenario)'],
#   'year': 1921},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfda'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Pomeroy Cannon',
#    'Josef Swickard',
#    'Bridgetta Clark',
#    'Rudolph Valentino'],
#   'countries': ['USA'],
#   'directors': ['Rex Ingram'],
#   'fullplot': 'Julio Madariaga is the Argentine patriarch of a wealthy family. He has two daughters, the elder wed to a Frenchman and the other to a German. He prefers the Frenchman and his family, especially his grandson Julio, causing jealousy from the German and his three sons. When Madariaga dies, the family splits up, each son-in-law returning to his own country. The Frenchman and his own move to Paris, where Julio becomes an artist and has an affair with an unhappily married woman, the lovely Marguerite Laurier. Her husband finds out, but before he can finalize a divorce, World War One rears its head and both sides of the family will endure great suffering in the conflict, especially since they must fight one another on the battlefield.',
#   'genres': ['Drama', 'Romance', 'War'],
#   'imdb': {'id': 12190, 'rating': 7.9, 'votes': 2475},
#   'languages': [''],
#   'lastupdated': '2015-08-24 00:59:30.430000000',
#   'num_mflix_comments': '',
#   'plot': 'An extended family split up in France and Germany find themselves on opposing sides of the battlefield during World War I.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTg0MTgyMDY0MV5BMl5BanBnXkFtZTgwOTk4OTcwMjE@._V1_SX300.jpg',
#   'rated': 'PASSED',
#   'released': datetime.datetime(1923, 3, 31, 0, 0),
#   'runtime': '150',
#   'title': 'The Four Horsemen of the Apocalypse',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Vicente Blasco Ib��ez (novel)',
#    'June Mathis (written for the screen by)'],
#   'year': 1921},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfe1'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Carl Miller',
#    'Edna Purviance',
#    'Jackie Coogan',
#    'Charles Chaplin'],
#   'countries': ['USA'],
#   'directors': ['Charles Chaplin'],
#   'fullplot': 'The opening title reads: "A comedy with a smile--and perhaps a tear". As she leaves the charity hospital and passes a church wedding, Edna deposits her new baby with a pleading note in a limousine and goes off to commit suicide. The limo is stolen by thieves who dump the baby by a garbage can. Charlie the Tramp finds the baby and makes a home for him. Five years later Edna has become an opera star but does charity work for slum youngsters in hope of finding her boy. A doctor called by Edna discovers the note with the truth about the Kid and reports it to the authorities who come to take him away from Charlie. Before he arrives at the Orphan Asylum Charlie steals him back and takes him to a flophouse. The proprietor reads of a reward for the Kid and takes him to Edna. Charlie is later awakened by a kind policeman who reunites him with the Kid at Edna\'s mansion.',
#   'genres': ['Comedy', 'Drama', 'Family'],
#   'imdb': {'id': 12349, 'rating': 8.4, 'votes': 56858},
#   'languages': ['English'],
#   'lastupdated': '2015-09-05 00:24:11.143000000',
#   'num_mflix_comments': '',
#   'plot': 'The Tramp cares for an abandoned child, but events put that relationship in jeopardy.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTkzNTgxMDU1OF5BMl5BanBnXkFtZTgwOTQ3MjI2MzE@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'released': datetime.datetime(1921, 2, 6, 0, 0),
#   'runtime': '68',
#   'title': 'The Kid',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Charles Chaplin'],
#   'year': 1921},
#  {'_id': ObjectId('5db003a2d0a60ca4acd0bfe5'),
#   'awards': {'nomination': None, 'text': '1 win.', 'win': ''},
#   'cast': ['Lois Wilson',
#    'Milton Sills',
#    'Theodore Roberts',
#    'Helen Ferguson'],
#   'countries': ['USA'],
#   'directors': ['William C. de Mille'],
#   'fullplot': 'Wlliam deMille produced and directed Miss Lulu Bett, a film of extraordinary conviction and insight. It was then often the custom for unmarried women to lodge with family; thus we discover Miss Lulu in a boring Midwestern town, an exploited household drudge for her sister and her overbearing brother-in-law. In the course of the story (based upon the Pulitzer Prize play and novel by Zona Gale), Lulu evolves from slavery into an attractive and self-assured woman, prepared to make her own life. Revealed through wonderful performances and clever use of props, the characters are extraordinarily solid and involving.',
#   'genres': ['Comedy', 'Drama'],
# ...
#   'languages': ['Swedish', 'French'],
#   'lastupdated': '2015-09-02 00:25:54.803000000',
#   'num_mflix_comments': '',
#   'plot': 'Rakel, Marta, Karin and Annette are married to four brothers. While waiting in a summer cottage for their husbands to come home, they tell each other stories about their marriages. Rakel ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTQ3Mzg0Mzg3MV5BMl5BanBnXkFtZTcwNTA4MjIyMQ@@._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1961, 7, 11, 0, 0),
#   'runtime': '107',
#   'title': 'Waiting Women',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Ingmar Bergman', 'Gun Grut (story)'],
#   'year': 1952},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce0e'),
#   'awards': {'nomination': '',
#    'text': 'Won 1 Oscar. Another 3 wins & 4 nominations.',
#    'win': ''},
#   'cast': ['Alec Guinness', 'Stanley Holloway', 'Sidney James', 'Alfie Bass'],
#   'countries': ['UK'],
#   'directors': ['Charles Crichton'],
#   'fullplot': "Holland, a shy retiring man, dreams of being rich and living the good life. Faithfully, for 20 years, he has worked as a bank transfer agent for the delivery of gold bullion. One day he befriends Pendlebury, a maker of souvenirs. Holland remarks that, with Pendlebury's smelting equipment, one could forge the gold into harmless-looking toy Eiffel Towers and smuggle the gold from England into France. Soon after, the two plant a story to gain the services of professional criminals Lackery and Shorty. Together, the four plot their crime, leading to unexpected twists and turns.",
#   'genres': ['Comedy', 'Crime'],
#   'imdb': {'id': 44829, 'rating': 7.8, 'votes': 9067},
#   'languages': ['English', 'French', 'Portuguese'],
#   'lastupdated': '2015-08-13 00:16:20.817000000',
#   'num_mflix_comments': '',
#   'plot': 'A meek bank clerk who oversees the shipment of bullion joins with an eccentric neighbor to steal gold bars and smuggle them out of the country as miniature Eifel Towers.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTY3OTUwMTg2OV5BMl5BanBnXkFtZTcwNjYwMDYyMQ@@._V1_SX300.jpg',
#   'rated': 'APPROVED',
#   'released': datetime.datetime(1951, 9, 10, 0, 0),
#   'runtime': '78',
#   'title': 'The Lavender Hill Mob',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['T.E.B. Clarke (original screenplay)'],
#   'year': 1951},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce12'),
#   'awards': {'nomination': '',
#    'text': 'Won 1 Oscar. Another 6 wins & 2 nominations.',
#    'win': ''},
#   'cast': ['Charles Chaplin', 'Claire Bloom', 'Nigel Bruce', 'Buster Keaton'],
#   'countries': ['USA'],
#   'directors': ['Charles Chaplin'],
#   'fullplot': "Chaplin's final American film tells the story of a fading music hall comedian's effort to help a despondent ballet dancer learn both to walk and feel confident about life again. The highlight of the film is the classic duet with Chaplin's only real artistic film comedy rival, Buster Keaton.",
#   'genres': ['Drama', 'Music'],
#   'imdb': {'id': 44837, 'rating': 8.1, 'votes': 12113},
#   'languages': ['English'],
#   'lastupdated': '2015-09-14 09:47:11.813000000',
#   'num_mflix_comments': '',
#   'plot': 'A fading comedian and a suicidally despondent ballet dancer must look to each other to find meaning and hope in their lives.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTQ3Mzc3Mjk3NV5BMl5BanBnXkFtZTgwNjA3NjQzMTE@._V1_SX300.jpg',
#   'rated': 'APPROVED',
#   'released': datetime.datetime(1952, 10, 29, 0, 0),
#   'runtime': '137',
#   'title': 'Limelight',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Charles Chaplin (original story and screenplay)'],
#   'year': 1952},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce15'),
#   'awards': {'nomination': '',
#    'text': 'Nominated for 1 Oscar. Another 1 win & 2 nominations.',
#    'win': ''},
#   'cast': ['Alec Guinness', 'Joan Greenwood', 'Cecil Parker', 'Michael Gough'],
#   'countries': ['UK'],
#   'directors': ['Alexander Mackendrick'],
#   'fullplot': "Sidney Stratton, a humble inventor, develops a fabric which never gets dirty or wears out. This would seem to be a boon for mankind, but the established garment manufacturers don't see it that way; they try to suppress it.",
#   'genres': ['Comedy', 'Sci-Fi', 'Drama'],
#   'imdb': {'id': 44876, 'rating': 7.4, 'votes': 6226},
#   'languages': ['English'],
#   'lastupdated': '2015-09-05 00:33:51.297000000',
#   'num_mflix_comments': '',
#   'plot': 'An altruistic chemist invents a fabric that resists wear and stain as boon to humanity but both capital and labor realize it must be suppressed for economic reasons.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTUxNTIzNzY4OV5BMl5BanBnXkFtZTgwODExMTI0NDE@._V1_SX300.jpg',
#   'rated': 'APPROVED',
#   'released': datetime.datetime(1952, 4, 1, 0, 0),
#   'runtime': '85',
#   'title': 'The Man in the White Suit',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Roger MacDougall (play)',
#    'Roger MacDougall (screenplay)',
#    'John Dighton (screenplay)',
#    'Alexander Mackendrick (screenplay)'],
#   'year': 1951},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce18'),
#   'awards': {'nomination': '',
#    'text': 'Nominated for 1 BAFTA Film Award. Another 1 nomination.',
#    'win': None},
#   'cast': ['Judy Holliday', 'Aldo Ray', 'Madge Kennedy', 'Sheila Bond'],
#   'countries': ['USA'],
#   'directors': ['George Cukor'],
#   'fullplot': 'Florence and Chet Keefer have had a troublesome marriage. Whilst in the middle of a divorce hearing the judge encourages them to remember the good times they have had hoping that the marriage can be saved.',
#   'genres': ['Comedy', 'Drama'],
#   'imdb': {'id': 44888, 'rating': 7, 'votes': 792},
#   'languages': ['English'],
#   'lastupdated': '2015-08-25 00:56:30.807000000',
#   'num_mflix_comments': '',
#   'plot': 'Florence and Chet Keefer have had a troublesome marriage. Whilst in the middle of a divorce hearing the judge encourages them to remember the good times they have had hoping that the ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BNzgzNDk5OTYwMl5BMl5BanBnXkFtZTYwMTkwMjg5._V1_SX300.jpg',
#   'rated': '',
#   'released': datetime.datetime(1952, 2, 1, 0, 0),
#   'runtime': '92',
#   'title': 'The Marrying Kind',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Ruth Gordon', 'Garson Kanin'],
#   'year': 1952},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce19'),
#   'awards': {'nomination': '',
#    'text': 'Nominated for 1 Oscar. Another 1 nomination.',
#    'win': None},
#   'cast': ['Gilbert Roland', 'Angela Clarke', 'Frank Silvera', 'Jay Novello'],
#   'countries': ['USA'],
#   'directors': ['John Brahm'],
#   'fullplot': 'In 1917, three shepherd children living just outside Fatima, Portugal have visions of a lovely lady in a cloud. The anticlerical government wishes to squelch the Church; reports of religious experiences are cause for serious concern. Yet the children stand by their story, and the message of peace and hope the Lady brings. In the last vision, attended by thousands of people, the Lady proves her reality with a spectacular miracle that is seen by everyone present. Based on actual events at Fatima in the summer of 1917.',
#   'genres': ['Drama'],
#   'imdb': {'id': 44905, 'rating': 6.9, 'votes': 657},
#   'languages': ['English'],
#   'lastupdated': '2015-08-03 00:25:33.333000000',
#   'num_mflix_comments': '',
#   'plot': 'In 1917, three shepherd children living just outside Fatima, Portugal have visions of a lovely lady in a cloud. The anticlerical government wishes to squelch the Church; reports of ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTc1MDAyOTEwNV5BMl5BanBnXkFtZTcwMTY5MzYzMQ@@._V1_SX300.jpg',
#   'rated': 'APPROVED',
#   'released': datetime.datetime(1952, 11, 6, 0, 0),
#   'runtime': '102',
#   'title': 'The Miracle of Our Lady of Fatima',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Crane Wilbur', "James O'Hanlon"],
#   'year': 1952},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce1a'),
#   'awards': {'nomination': None,
#    'text': 'Nominated for 1 Oscar. Another 1 win.',
#    'win': ''},
#   'cast': ['Ethel Waters', 'Julie Harris', 'Brandon De Wilde', 'Arthur Franz'],
#   'countries': ['USA'],
#   'directors': ['Fred Zinnemann'],
#   'fullplot': 'In a small Georgia town, twelve year old tomboy Frankie Addams feels unconnected to the world, a fact troubling to her. Her unconventional views for a twelve year old girl make her an outcast among her peers, which she in turn blames for her situation rather than anything of her own doing. Her only real friend is John Henry, her younger next door neighbor, although she doesn\'t see him as a friend since she doesn\'t consider him a peer. As her widowed father is all consumed with running his small business, Frankie is largely left to the care of their housekeeper, Berenice. Berenice tries to provide as much true guidance to Frankie and what Frankie considers her problems, although Berenice has her own troubles looking after her wild foster brother, Honey Camden, her only surviving family. In addition, Frankie largely sees Berenice\'s advice as the rantings of a large, crazy black woman. Frankie believes that she has finally found her place in life upon the return to town and announcement by her older enlisted brother Jarvis that he is getting married to a woman named Janice. Immediately upon seeing Jarvis and Janice together, she falls in love with "them", believing she can be a "member" of "them" by leaving town with them immediately following the wedding. Frankie even wants to change her name to Jasmine to feel more connected to them as they will all then have a name "Ja__". Two negative situations following the wedding - one in reaction to her finding out that she can\'t go with Jarvis and Janice - may however put Frankie in the right direction to truly finding her place in life.',
#   'genres': ['Drama'],
#   'imdb': {'id': 44896, 'rating': 7.1, 'votes': 922},
#   'languages': ['English'],
#   'lastupdated': '2015-08-21 00:56:07.673000000',
#   'num_mflix_comments': '',
#   'plot': "A young tomboy named Frankie is forced to face her own immaturity as a result her older brother's wedding.",
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTU2MDYyOTQzM15BMl5BanBnXkFtZTcwOTI0MjEyMQ@@._V1_SX300.jpg',
#   'rated': 'TV-G',
#   'released': '',
#   'runtime': '93',
#   'title': 'The Member of the Wedding',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Edna Anhalt (screenplay)',
#    'Edward Anhalt (screenplay)',
#    'Carson McCullers (novel)',
#    'Carson McCullers (play)'],
#   'year': 1952},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce1b'),
#   'awards': {'nomination': None,
#    'text': 'Nominated for 1 Oscar. Another 1 win.',
#    'win': ''},
#   'cast': ['Esther Williams',
#    'Victor Mature',
#    'Walter Pidgeon',
#    'David Brian'],
#   'countries': ['USA'],
#   'directors': ['Mervyn LeRoy'],
#   'fullplot': 'Million Dollar Mermaid tells the story of Australian swimming sensation Annette Kellerman, who overcame childhood polio to go on and achieve fame as a professional swimmer and film star in the early decades of the 20th century. At the same time, she scandalized the world by wearing a one-piece bathing suit on public beaches long before the style was accepted in polite company, and made waves in other ways as well. The story was a perfect vehicle decades later to showcase the star quality of Esther Williams in the 1950s, and Kellerman\'s moniker was picked up by Life Magazine when it named Ms. Williams the "Million Dollar Mermaid" herself.',
#   'genres': ['Biography', 'Drama', 'Musical'],
#   'imdb': {'id': 44903, 'rating': 6.5, 'votes': 828},
#   'languages': ['English'],
#   'lastupdated': '2015-08-24 00:57:11.667000000',
#   'num_mflix_comments': '',
#   'plot': 'Biopic of Australian swimming champ and entertainer Annette Kellerman. After overcoming polio, Kellerman achieves fame and creates a scandal when her one-piece bathing suit is considered indecent.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTg5NTAwNzI5MF5BMl5BanBnXkFtZTcwMzMyNTM2OQ@@._V1_SX300.jpg',
#   'rated': 'APPROVED',
#   'released': datetime.datetime(1953, 4, 15, 0, 0),
#   'runtime': '115',
#   'title': 'Million Dollar Mermaid',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Everett Freeman (screenplay)'],
#   'year': 1952},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce1f'),
#   'awards': {'nomination': '',
#    'text': 'Won 2 Oscars. Another 4 wins & 10 nominations.',
#    'win': ''},
#   'cast': ['Jos� Ferrer', 'Colette Marchand', 'Zsa Zsa Gabor', 'Suzanne Flon'],
#   'countries': ['UK'],
#   'directors': ['John Huston'],
#   'fullplot': "Henri de Toulouse-Lautrec frequently visits the Moulin Rouge, where he drinks cognac and draws sketches of the dancers and singers. Though the son of a French count, Henri's legs were badly deformed by a childhood fall, and his personal life is often unhappy as a result. While he is going home one night, a spirited young woman of the streets, Marie, asks him for help. He falls in love with her, and the two become involved in a tumultuous relationship. It becomes increasingly difficult for Toulouse-Lautrec to balance his personal feelings, his artistic abilities, and his family name and position.",
#   'genres': ['Biography', 'Drama', 'Music'],
#   'imdb': {'id': 44926, 'rating': 7.2, 'votes': 3574},
#   'languages': ['English'],
#   'lastupdated': '2015-09-02 00:29:22.320000000',
#   'num_mflix_comments': '',
#   'plot': 'Fictional account of French artist Henri de Toulouse-Lautrec.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTY2ODk2NDQxNl5BMl5BanBnXkFtZTgwODUwNDkyMjE@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'released': datetime.datetime(1952, 12, 23, 0, 0),
#   'runtime': '119',
#   'title': 'Moulin Rouge',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Pierre La Mure (novel)',
#    'Anthony Veiller (screenplay)',
#    'John Huston (screenplay)'],
#   'year': 1952},
#  {'_id': ObjectId('5db003c0d0a60ca4acd0ce23'),
#   'awards': {'nomination': '',
#    'text': 'Nominated for 4 Oscars. Another 1 win & 1 nomination.',
#    'win': ''},
#   'cast': ['Olivia de Havilland',
#    'Richard Burton',
#    'Audrey Dalton',
#    'Ronald Squire'],
#   'countries': ['USA'],
#   'directors': ['Henry Koster'],
#   'fullplot': "When Philip Ashley's much-loved (and rich) cousin Ambrose dies, he is convinced that Ambrose was murdered by his new wife Rachel to inherit his wealth. But when he meets Rachel and falls in love with her, he knows that his suspicions must have been unfounded. But were they, or is Rachel just trying to use Philip to get at the estate Ambrose left to him instead of to her? And will she murder him next?",
#   'genres': ['Mystery', 'Romance', 'Drama'],
#   'imdb': {'id': 44937, 'rating': 7.2, 'votes': 1176},
#   'languages': ['English', 'Italian'],
#   'lastupdated': '2015-08-26 00:09:40.167000000',
#   'num_mflix_comments': '',
#   'plot': 'A young man plots revenge against the woman he believes murdered his cousin, but his plans are shaken when he comes face to face with the enigmatic beauty.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjcxMTU4OTI5MF5BMl5BanBnXkFtZTgwNzU1Nzk1MDE@._V1_SX300.jpg',
#   'rated': 'APPROVED',
#   'released': datetime.datetime(1954, 12, 24, 0, 0),
#   'runtime': '98',
#   'title': 'My Cousin Rachel',
#   'tomatoes': {'lastUpdated': '',
#    'viewer': {'meter': '', 'numReviews': '', 'rating': ''}},
#   'type': 'movie',
#   'writers': ['Nunnally Johnson (screen play)',
#    'Daphne Du Maurier (from the novel by)'],
#   'year': 1952},
#  ...]

# %%
query = {'$sort': { '_id': 1 }}
projection = {'_id':1,
             'awards':1,
             'cast':1,
             'countries':1,
             'directors':1,
             'fullplot':1,
             'genres':1,
             'imdb':1,
             'languages':1,
             'lastupdated':1,
             'metacritic':1,
             'num_mflix_comments':1,
             'plot':1,
             'poster':1,
             'rated':1,
             'released':1,
             'runtime':1,
             'title':1,
             'tomatoes':1,
             'type':1,
             'writers':1,
             'year':1}

proj=client.sample_mflix.clean_movies_hania.find({},projection)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-41-dfc418377e1a> in <module>()
#      25 # save to array
#      26 val=[]
# ---> 27 for x in col_movies.find(query, projection) :
#      28     val.append(x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1154         if self.__empty:
#    1155             raise StopIteration
# -> 1156         if len(self.__data) or self._refresh():
#    1157             if self.__manipulate:
#    1158                 _db = self.__collection.database
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1071                                   self.__session,
#    1072                                   self.__collection.database.client)
# -> 1073             self.__send_message(q)
#    1074         elif self.__id:  # Get More
#    1075             if self.__limit:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#     953             response = client._run_operation_with_response(
#     954                 operation, self._unpack_response, exhaust=self.__exhaust,
# --> 955                 address=self.__address)
#     956         except OperationFailure:
#     957             self.__killed = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1345             address=address,
#    1346             retryable=isinstance(operation, message._Query),
# -> 1347             exhaust=exhaust)
#    1348
#    1349     def _retry_with_session(self, retryable, func, session, bulk):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1463                         # not support retryable reads, raise the last error.
#    1464                         raise last_error
# -> 1465                     return func(session, server, sock_info, slave_ok)
#    1466             except ServerSelectionTimeoutError:
#    1467                 if retrying:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _cmd(session, server, sock_info, slave_ok)
#    1339                 self._event_listeners,
#    1340                 exhaust,
# -> 1341                 unpack_res)
#    1342
#    1343         return self._retryable_read(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\server.py in run_operation_with_response(self, sock_info, operation, set_slave_okay, listeners, exhaust, unpack_res)
#     134                 operation.client._process_response(
#     135                     first, operation.session)
# --> 136                 _check_command_response(first)
#     137         except Exception as exc:
#     138             if publish:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     157
#     158             msg = msg or "%s"
# --> 159             raise OperationFailure(msg % errmsg, code, response)
#     160
#     161
#
# OperationFailure: unknown top level operator: $sort

# %%
val
# Out:
# []
